# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# 1. Learning rate
# 2. Slope of a  function

# %%
from sklearn.datasets import make_regression
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
X,y=make_regression(n_samples=100,n_features=1,n_informative=1,n_targets=1,noise=20)

from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,y,test_size=0.2,random_state=2)

# %%
plt.scatter(X,y)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(X_train,Y_train)
print(lr.coef_)
print(lr.intercept_)
# Out:
# [85.27651831]
# 2.0989619502727432

# %%
y_pred=lr.predict(X_test)
from sklearn.metrics import r2_score
r2_score(Y_test,y_pred)
# Out:
# 0.9429799667281059

# %%
class GDRegressor:

# learning rate , number of iterations
  def __init__(self,learning_rate,epoch):
    self.m=57.36
    self.b=-120
    self.learning_rate=learning_rate
    self.epoch=epoch

  def fit(self,X,Y):

    # calculate b using epoch

    for i in range(self.epoch):
      loss_slope = -2* np.sum(y-self.m*X.ravel() - self.b)
      self.b=self.b- self.learning_rate*loss_slope
      print(loss_slope,"-->",self.b)

    print(self.b)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
gd2=GDRegressor(0.001,100)
gd2.fit(X,y)
# Out:
# -24440.731121879315 --> -95.55926887812069
# -19552.58489750345 --> -76.00668398061724
# -15642.06791800276 --> -60.36461606261448
# -12513.65433440221 --> -47.85096172821227
# -10010.923467521767 --> -37.840038260690505
# -8008.738774017413 --> -29.831299486673093
# -6406.991019213931 --> -23.424308467459163
# -5125.592815371146 --> -18.298715652088017
# -4100.474252296915 --> -14.198241399791101
# -3280.3794018375334 --> -10.917861997953567
# -2624.303521470026 --> -8.293558476483541
# -2099.442817176021 --> -6.194115659307521
# -1679.5542537408169 --> -4.514561405566703
# -1343.643402992654 --> -3.1709180025740493
# -1074.9147223941227 --> -2.096003280179927
# -859.9317779152981 --> -1.236071502264629
# -687.9454223322386 --> -0.5481260799323903
# -550.3563378657907 --> 0.0022302579334004813
# -440.2850702926327 --> 0.44251532822603323
# -352.228056234106 --> 0.7947433844601393
# -281.7824449872851 --> 1.0765258294474243
# -225.42595598982797 --> 1.3019517854372522
# -180.3407647918621 --> 1.4822925502291144
# -144.27261183348978 --> 1.6265651620626043
# -115.41808946679184 --> 1.741983251529396
# -92.3344715734335 --> 1.8343177231028296
# -73.86757725874712 --> 1.9081853003615767
# -59.094061806997466 --> 1.9672793621685742
# -47.27524944559801 --> 2.014554611614172
# -37.820199556478244 --> 2.0523748111706506
# -30.256159645182706 --> 2.0826309708158335
# -24.204927716146074 --> 2.1068358985319797
# -19.363942172916552 --> 2.126199840704896
# -15.49115373833341 --> 2.1416909944432296
# -12.392922990666904 --> 2.1540839174338964
# -9.914338392533793 --> 2.16399825582643
# -7.931470714027043 --> 2.171929726540457
# -6.345176571221643 --> 2.178274903111679
# -5.0761412569771664 --> 2.183351044368656
# -4.060913005581767 --> 2.1874119573742377
# -3.248730404465263 --> 2.1906606877787027
# -2.598984323572367 --> 2.193259672102275
# -2.0791874588581294 --> 2.195338859561133
